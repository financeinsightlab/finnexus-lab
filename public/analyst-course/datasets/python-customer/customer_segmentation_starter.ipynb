# %% [markdown]
# # Customer Segmentation — Python Analytics Lab
# Work through the guided tasks in SignalPath. Keep raw files unchanged and document every cleaning rule.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

customers = pd.read_csv('customers.csv')
transactions = pd.read_csv('transactions.csv')

# %% [markdown]
# ## 1. Profile and clean
# Add checks for shape, dtypes, nulls, duplicates, invalid customer IDs, and inconsistent regions.

# %%
# Your code here

# %% [markdown]
# ## 2. Aggregate to customer grain
# Calculate transaction count, total spend, average transaction value, and recency before joining to customer attributes.

# %%
# Your code here

# %% [markdown]
# ## 3. Segment, visualize, and recommend
# Use evidence and business context. A cluster label is not a strategy by itself.

# %%
# Your code here
